# %%
from wordcloud import WordCloud, STOPWORDS

import os
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import itertools
import collections

import tweepy as tw
import nltk
from nltk.corpus import stopwords
from nltk import bigrams
import re
import networkx as nx
from textblob import TextBlob, Word, Blobber

import warnings
warnings.filterwarnings("ignore")


# For more info on how TextBlob works see:  https://github.com/sloria/TextBlob



sns.set(font_scale=1.5)
sns.set_style("whitegrid")

nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Chris\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\stopwords.zip.
# True

# %%
consumer_key= 'XgLfVqV7ADXpG5EHnMgyx3xwo'
consumer_secret= '870pskWxaItAxxqdeHK5bbLcfvAv41mSDKgzl9t0YH47ImCHKS'
access_token= '56790330-wAee8FiCqQp6AIlaXDrZHfJVa5IDmMwmlPmU2fOqG'
access_token_secret= 'lCfFwqHmMCxREpuicnyC2Hs6o4OlVUi0hnzle5Xk24r8n'

# %%
auth = tw.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)
api = tw.API(auth, wait_on_rate_limit=True)

# %%
# The Twitter API only allows you to access the past few weeks of tweets unless you purchase the premium API


search_term = "#federalreserve -filter:retweets"
date_since = "2019-11-30"

tweets = tw.Cursor(api.search,
                   q=search_term,
                   lang="en",
                   since=date_since).items(500)

all_tweets = [tweet.text for tweet in tweets]

all_tweets[:50]
# Out:
# ['Make sure you guys invest in #Gold. A #UnitedStates owned #FederalReserve with a Gold backed note will likely be th… https://t.co/Ba5BSY5Lbg',
#  '#newsuneed #recession #projections #money #Federalreserve #interestrate #economy #USA #US\nWhile we can only hope th… https://t.co/08m9cMcF3n',
#  'Listen to The Legal Nature of Money and the History of the Federal Reserve with @rohangrey by Macro n Cheese on… https://t.co/X5LQfW1vqH',
#  '@zatzi I’m telling’ ya, Zatzi —\n🇺🇸 doesn’t DESERVE to be the blood and muscle of THE EMPIRE.\nPlease— take it back!… https://t.co/DQhWxH7Hmp',
#  'Card Late Payers Continue to Rise Despite Job Glut https://t.co/85iUb1Sxzh #delinquency #Q3 #federalreserve… https://t.co/Hd6oNAzWNs',
#  'Which monetary policy has been more expansionary in the past 36 months? A look at the growth in the money supply sh… https://t.co/nD9vCjIrVT',
#  '5000 years history of Global Interest Rates \u2066@IanRobinson\u2069 #FederalReserve \u2066@RBAInfo\u2069 #interestrates  https://t.co/6hqxAsGKmZ',
#  'Federal Reserve Considers Creating a Separate Entity for Cash Injections - https://t.co/kJeBIfetQV #Banking #Banks… https://t.co/d2I4hU91fz',
#  'Watch Net Lease TV - https://t.co/ppsWDkk4dF\n\n#monetarypolicy #markets #bonds #investor #privateequity #options… https://t.co/W94CEYp4Ca',
#  'Brainard shares Fed’s thinking on CRA rule reform, reiterates push for single set of standards #FederalReserve https://t.co/S830ZnbPCZ',
#  "Nov consumer credit: Ancient history, but Fed's rpt just now shows overall increase at 3.6% annual rate, not the un… https://t.co/kp3kZvrkU0",
#  'Credit Card Losses Tick Up to New Highs Despite Economy https://t.co/y63rgNYSFR citibank @chase capitalone bankofam… https://t.co/MvKiNt6shM',
#  'You are going to want to tune into Making Money tomorrow at 2:15p ET.. I have an exclusive one on one interview wit… https://t.co/7o7iCpjJ3K',
#  'You are going to want to tune into Making Money tomorrow at 2:15p ET.. I have an exclusive one on one interview wit… https://t.co/zmuUOT448A',
#  '[Video] How familiar are you with the Federal Reserve? Here’s a quick history. #fed #federalreserve #fedpolicy https://t.co/mO5e3YU2E1',
#  'FUCK YOU #FEDERALRESERVE IM NOT PAYING TAXES ANYMORE!  YOU KEEP THIS MARKET PROPPED UP WITH OUR MONEY AND WHEN IT G… https://t.co/jb7hQNAhUm',
#  'Secrets of the Temple:  How the Federal Reserve works. #FederalReserve https://t.co/5o9iHePHaC',
#  'The Lost Decade\n#Thelostdecade #PujaMehra #CentreforPolicyResearch\n@CDS_Bath #LehmanBrothers #MerrillLynch… https://t.co/SZhgXSH7UI',
#  '@BenjaminNorton Our flawed #ForeignPolicy is due to decades of warmongering by corporate interests &amp;… https://t.co/rg7o6IDwQP',
#  '#FEDERALRESERVE ADMITS IT PUMPED MORE THAN $6 TRILLION TO #WALLSTREET IN RECENT SIX WEEK PERIOD\n\nhttps://t.co/7zUkAA9G48',
#  'Sanctions against #Iran is like the #federalReserve interest rate not much else that can be done unless of course y… https://t.co/BhkBoU0ooN',
#  '@Amy_Siskind Trump bullies so many: NFL owners, Big Oil CEOs, Senators, GOP, Federal Reserve, Wall Street?\n\nMany in… https://t.co/F7HnpFI8EZ',
#  '#FederalReserve: Brainard, Strengthening the Community Reinvestment Act by Staying True to Its Core Purpose https://t.co/KmE3QzHt7V',
#  '#FederalReserve: FEDS 2020-003: Short-term Planning, Monetary Policy, and Macroeconomic Persistence https://t.co/ppsBYG67vJ',
#  'Turkey Treasury Cash Balance fell from previous 7.9B to -36.77B in Decemb...   https://t.co/pM1eC5koTx #Investing #FederalReserve',
#  'Bond Report: Treasury yields off session lows as traders shrug off Iran r...   https://t.co/aVidlTAwR8 #Investing #FederalReserve',
#  'Rabobank sees Fed cutting rates to zero before the end of 2020.\n#FederalReserve #InterestRates #Economy… https://t.co/cJF7X50Doc',
#  'The Lost Decade\n#Thelostdecade #PujaMehra #CentreforPolicyResearch\n@CDS_Bath #LehmanBrothers #MerrillLynch… https://t.co/8PbpLRmt1S',
#  'Great way to kick off 2020 w @MariaBartiromo @kevinolearytv\nCabot Phillips and Dagen McDowell this morning on Fox B… https://t.co/IKATICkg7H',
#  'Time travelling Nazis are robbing everyone with GMOs to hide the moon base.  #FederalReserve',
#  'No, I’m sure he meant his personal economy...maybe? #trumptaxes #GOPTaxScam #deficit #FederalReserve https://t.co/Z5Vt3AY6Ou',
#  "☎ [WEDNESDAY PREVIEW CALL] Risk markets continue to hold up in the face of downside risk. Key tags on today's call… https://t.co/0zgshyDvAW",
#  '@gatewaypundit @Snikk #Democrats are firing up the printing presses at #FederalReserve to print out bullions is dol… https://t.co/HtxBMd3OX9',
#  'The Lost Decade\n#Thelostdecade #PujaMehra #CentreforPolicyResearch\n@CDS_Bath #LehmanBrothers #MerrillLynch… https://t.co/z5svd5hBYD',
#  'This is what I was watching on Tuesday, January 7th, 2019. \n\nFederal Reserve jumps into the repo market again...… https://t.co/RopIv6Ti0s',
#  '@FeryFCK @CredibleCrypto I think this is true in part - But I believe its primarily because Iran, Cuba and North Ko… https://t.co/0wCHGI3BPG',
#  'The matrix has you Neo! Follow the white rabbit!\n\n#revolution #wakeup #2020vision #fakenews #questioneverything… https://t.co/KEH17Yguqo',
#  'This is at the core of everything!\n#TrumpVsDeepState\n#CentralBank\n#FederalReserve\n@Shantstan @WarNuse @mac17_o… https://t.co/6qmsaLtNS8',
#  "Does anyone else find it odd that both sides announce what they're about to do. What happened to not telling your e… https://t.co/3N2m8Kz3ZF",
#  '$SPX $SPY $AAPL $MSFT multiples not even 1/3rd of $AMZN? What war? #FederalReserve ?',
#  '@pksbitcoin 💯 \n\nMoney is so broken \n\nNothing more manipulated than USD #NotQE #FederalReserve\n\nOwning BTC via priva… https://t.co/tlpyT2YgKF',
#  'Bond Report: Treasury yields tick higher on service sector strength and d...   https://t.co/EQu5RGYc9u #Investing #FederalReserve',
#  "Is the\n\nNY #FederalReserve's #REPO Loan Ramp\n&amp; \n#JPMorgan's #Silver RICO Act Charges by US DoJ \n\nSimultaneous Timin… https://t.co/Scx8wVJPtY",
#  'The #FederalReserve expects to refrain from any changes in its target rate for the whole 2020. Yet, markets see a 5… https://t.co/l4aoH3a7eU',
#  '#Bitcoin fixes this.\n\n#FederalReserve Admits It Pumped More than $6 Trillion to Wall Street in Recent Six Week Peri… https://t.co/wjhIzcgJqM',
#  "@realDonaldTrump @GOPLeader @foxandfriends #FederalReserve report finds #Trump's #tariffs #Raised Prices, cut… https://t.co/7CVUv77SOC",
#  'Trade War Biggest Blunder Ever Costing U.S. Bigly https://t.co/xZxFd52deC #tariffs #federalreserve #princeton… https://t.co/1z9DnvKqMz',
#  '#CNBC #FoxBusiness #Federalreserve  #bailyourselfoutnexttime #BANKS no more FED REPO! https://t.co/HX8uwFMlvw',
#  'The Lost Decade\n#Thelostdecade #PujaMehra #CentreforPolicyResearch\n@CDS_Bath #LehmanBrothers #MerrillLynch… https://t.co/2ec4XTXbG7',
#  'Whomever is trying to destroy the #FederalReserve with foreign currency swaps is back.\n\nThey probably exited the re… https://t.co/cC3By4Kxen']

# %%
def remove_url(txt):
    return " ".join(re.sub("([^0-9A-Za-z \t])|(\w+:\/\/\S+)", "", txt).split())
all_tweets_no_urls = [remove_url(tweet) for tweet in all_tweets]

# %%
# Create a list of lists containing lowercase words for each tweet
words_in_tweet = [tweet.lower().split() for tweet in all_tweets_no_urls]
words_in_tweet[:2]
# Out:
# [['make',
#   'sure',
#   'you',
#   'guys',
#   'invest',
#   'in',
#   'gold',
#   'a',
#   'unitedstates',
#   'owned',
#   'federalreserve',
#   'with',
#   'a',
#   'gold',
#   'backed',
#   'note',
#   'will',
#   'likely',
#   'be',
#   'th'],
#  ['newsuneed',
#   'recession',
#   'projections',
#   'money',
#   'federalreserve',
#   'interestrate',
#   'economy',
#   'usa',
#   'uswhile',
#   'we',
#   'can',
#   'only',
#   'hope',
#   'th']]

# %%
# List of all words across tweets
all_words_no_urls = list(itertools.chain(*words_in_tweet))

# Create counter
counts_no_urls = collections.Counter(all_words_no_urls)

clean_tweets_no_urls = pd.DataFrame(counts_no_urls.most_common(15),
                             columns=['words', 'count'])

# %%
fig, ax = plt.subplots(figsize=(8, 8))

# Plot horizontal bar graph
clean_tweets_no_urls.sort_values(by='count').plot.barh(x='words',
                      y='count',
                      ax=ax,
                      color="orange")

ax.set_title("Common Words Found in Tweets (Including All Words)")

plt.show()

# %%
stop_words = set(stopwords.words('english'))

# %%
# Remove stop words from each tweet list of words
tweets_nsw = [[word for word in tweet_words if not word in stop_words]
              for tweet_words in words_in_tweet]
tweets_nsw
# Out:
# [['make',
#   'sure',
#   'guys',
#   'invest',
#   'gold',
#   'unitedstates',
#   'owned',
#   'federalreserve',
#   'gold',
#   'backed',
#   'note',
#   'likely',
#   'th'],
#  ['newsuneed',
#   'recession',
#   'projections',
#   'money',
#   'federalreserve',
#   'interestrate',
#   'economy',
#   'usa',
#   'uswhile',
#   'hope',
#   'th'],
#  ['listen',
#   'legal',
#   'nature',
#   'money',
#   'history',
#   'federal',
#   'reserve',
#   'rohangrey',
#   'macro',
#   'n',
#   'cheese'],
#  ['zatzi',
#   'im',
#   'telling',
#   'ya',
#   'zatzi',
#   'doesnt',
#   'deserve',
#   'blood',
#   'muscle',
#   'empireplease',
#   'take',
#   'back'],
#  ['card',
#   'late',
#   'payers',
#   'continue',
#   'rise',
#   'despite',
#   'job',
#   'glut',
#   'delinquency',
#   'q3',
#   'federalreserve'],
#  ['monetary',
#   'policy',
#   'expansionary',
#   'past',
#   '36',
#   'months',
#   'look',
#   'growth',
#   'money',
#   'supply',
#   'sh'],
#  ['5000',
#   'years',
#   'history',
#   'global',
#   'interest',
#   'rates',
#   'ianrobinson',
#   'federalreserve',
#   'rbainfo',
#   'interestrates'],
#  ['federal',
#   'reserve',
#   'considers',
#   'creating',
#   'separate',
#   'entity',
#   'cash',
#   'injections',
#   'banking',
#   'banks'],
#  ['watch',
#   'net',
#   'lease',
#   'tv',
#   'monetarypolicy',
#   'markets',
#   'bonds',
#   'investor',
#   'privateequity',
#   'options'],
#  ['brainard',
#   'shares',
#   'feds',
#   'thinking',
#   'cra',
#   'rule',
#   'reform',
#   'reiterates',
#   'push',
#   'single',
#   'set',
#   'standards',
#   'federalreserve'],
#  ['nov',
#   'consumer',
#   'credit',
#   'ancient',
#   'history',
#   'feds',
#   'rpt',
#   'shows',
#   'overall',
#   'increase',
#   '36',
#   'annual',
#   'rate',
#   'un'],
#  ['credit',
#   'card',
#   'losses',
#   'tick',
#   'new',
#   'highs',
#   'despite',
#   'economy',
#   'citibank',
#   'chase',
#   'capitalone',
#   'bankofam'],
#  ['going',
#   'want',
#   'tune',
#   'making',
#   'money',
#   'tomorrow',
#   '215p',
#   'et',
#   'exclusive',
#   'one',
#   'one',
#   'interview',
#   'wit'],
#  ['going',
#   'want',
#   'tune',
#   'making',
#   'money',
#   'tomorrow',
#   '215p',
#   'et',
#   'exclusive',
#   'one',
#   'one',
#   'interview',
#   'wit'],
#  ['video',
#   'familiar',
#   'federal',
#   'reserve',
#   'heres',
#   'quick',
#   'history',
#   'fed',
#   'federalreserve',
#   'fedpolicy'],
#  ['fuck',
#   'federalreserve',
#   'im',
#   'paying',
#   'taxes',
#   'anymore',
#   'keep',
#   'market',
#   'propped',
#   'money',
#   'g'],
#  ['secrets', 'temple', 'federal', 'reserve', 'works', 'federalreserve'],
#  ['lost',
#   'decadethelostdecade',
#   'pujamehra',
#   'centreforpolicyresearchcdsbath',
#   'lehmanbrothers',
#   'merrilllynch'],
#  ['benjaminnorton',
#   'flawed',
#   'foreignpolicy',
#   'due',
#   'decades',
#   'warmongering',
#   'corporate',
#   'interests',
#   'amp'],
#  ['federalreserve',
#   'admits',
#   'pumped',
#   '6',
#   'trillion',
#   'wallstreet',
#   'recent',
#   'six',
#   'week',
#   'period'],
#  ['sanctions',
#   'iran',
#   'like',
#   'federalreserve',
#   'interest',
#   'rate',
#   'much',
#   'else',
#   'done',
#   'unless',
#   'course'],
#  ['amysiskind',
#   'trump',
#   'bullies',
#   'many',
#   'nfl',
#   'owners',
#   'big',
#   'oil',
#   'ceos',
#   'senators',
#   'gop',
#   'federal',
#   'reserve',
#   'wall',
#   'streetmany'],
#  ['federalreserve',
#   'brainard',
#   'strengthening',
#   'community',
#   'reinvestment',
#   'act',
#   'staying',
#   'true',
#   'core',
#   'purpose'],
#  ['federalreserve',
#   'feds',
#   '2020003',
#   'shortterm',
#   'planning',
#   'monetary',
#   'policy',
#   'macroeconomic',
#   'persistence'],
#  ['turkey',
#   'treasury',
#   'cash',
#   'balance',
#   'fell',
#   'previous',
#   '79b',
#   '3677b',
#   'decemb',
#   'investing',
#   'federalreserve'],
#  ['bond',
#   'report',
#   'treasury',
#   'yields',
#   'session',
#   'lows',
#   'traders',
#   'shrug',
#   'iran',
#   'r',
#   'investing',
#   'federalreserve'],
#  ['rabobank',
#   'sees',
#   'fed',
#   'cutting',
#   'rates',
#   'zero',
#   'end',
#   '2020federalreserve',
#   'interestrates',
#   'economy'],
#  ['lost',
#   'decadethelostdecade',
#   'pujamehra',
#   'centreforpolicyresearchcdsbath',
#   'lehmanbrothers',
#   'merrilllynch'],
#  ['great',
#   'way',
#   'kick',
#   '2020',
#   'w',
#   'mariabartiromo',
#   'kevinolearytvcabot',
#   'phillips',
#   'dagen',
#   'mcdowell',
#   'morning',
#   'fox',
#   'b'],
#  ['time',
#   'travelling',
#   'nazis',
#   'robbing',
#   'everyone',
#   'gmos',
#   'hide',
#   'moon',
#   'base',
#   'federalreserve'],
#  ['im',
#   'sure',
#   'meant',
#   'personal',
#   'economymaybe',
#   'trumptaxes',
#   'goptaxscam',
#   'deficit',
#   'federalreserve'],
#  ['wednesday',
#   'preview',
#   'call',
#   'risk',
#   'markets',
#   'continue',
#   'hold',
#   'face',
#   'downside',
#   'risk',
#   'key',
#   'tags',
#   'todays',
#   'call'],
#  ['gatewaypundit',
#   'snikk',
#   'democrats',
#   'firing',
#   'printing',
#   'presses',
#   'federalreserve',
#   'print',
#   'bullions',
#   'dol'],
#  ['lost',
#   'decadethelostdecade',
#   'pujamehra',
#   'centreforpolicyresearchcdsbath',
#   'lehmanbrothers',
#   'merrilllynch'],
#  ['watching',
#   'tuesday',
#   'january',
#   '7th',
#   '2019',
#   'federal',
#   'reserve',
#   'jumps',
#   'repo',
#   'market'],
#  ['feryfck',
#   'crediblecrypto',
#   'think',
#   'true',
#   'part',
#   'believe',
#   'primarily',
#   'iran',
#   'cuba',
#   'north',
#   'ko'],
#  ['matrix',
#   'neo',
#   'follow',
#   'white',
#   'rabbitrevolution',
#   'wakeup',
#   '2020vision',
#   'fakenews',
#   'questioneverything'],
#  ['core',
#   'everythingtrumpvsdeepstatecentralbankfederalreserveshantstan',
#   'warnuse',
#   'mac17o'],
#  ['anyone',
#   'else',
#   'find',
#   'odd',
#   'sides',
#   'announce',
#   'theyre',
#   'happened',
#   'telling',
#   'e'],
#  ['spx',
#   'spy',
#   'aapl',
#   'msft',
#   'multiples',
#   'even',
#   '13rd',
#   'amzn',
#   'war',
#   'federalreserve'],
#  ['pksbitcoin',
#   'money',
#   'broken',
#   'nothing',
#   'manipulated',
#   'usd',
#   'notqe',
#   'federalreserveowning',
#   'btc',
#   'via',
#   'priva'],
#  ['bond',
#   'report',
#   'treasury',
#   'yields',
#   'tick',
#   'higher',
#   'service',
#   'sector',
#   'strength',
#   'investing',
#   'federalreserve'],
#  ['theny',
#   'federalreserves',
#   'repo',
#   'loan',
#   'rampamp',
#   'jpmorgans',
#   'silver',
#   'rico',
#   'act',
#   'charges',
#   'us',
#   'doj',
#   'simultaneous',
#   'timin'],
#  ['federalreserve',
#   'expects',
#   'refrain',
#   'changes',
#   'target',
#   'rate',
#   'whole',
#   '2020',
#   'yet',
#   'markets',
#   'see',
#   '5'],
#  ['bitcoin',
#   'fixes',
#   'thisfederalreserve',
#   'admits',
#   'pumped',
#   '6',
#   'trillion',
#   'wall',
#   'street',
#   'recent',
#   'six',
#   'week',
#   'peri'],
#  ['realdonaldtrump',
#   'gopleader',
#   'foxandfriends',
#   'federalreserve',
#   'report',
#   'finds',
#   'trumps',
#   'tariffs',
#   'raised',
#   'prices',
#   'cut'],
#  ['trade',
#   'war',
#   'biggest',
#   'blunder',
#   'ever',
#   'costing',
#   'us',
#   'bigly',
#   'tariffs',
#   'federalreserve',
#   'princeton'],
#  ['cnbc',
#   'foxbusiness',
#   'federalreserve',
#   'bailyourselfoutnexttime',
#   'banks',
#   'fed',
#   'repo'],
#  ['lost',
#   'decadethelostdecade',
#   'pujamehra',
#   'centreforpolicyresearchcdsbath',
#   'lehmanbrothers',
#   'merrilllynch'],
#  ['whomever',
#   'trying',
#   'destroy',
#   'federalreserve',
#   'foreign',
#   'currency',
#   'swaps',
#   'backthey',
#   'probably',
#   'exited'],
#  ['officialmcafee',
#   'unbearableguy',
#   'youre',
#   'target',
#   'thoughcops',
#   'construction',
#   'workers',
#   'etc',
#   'work',
#   'us',
#   'pe'],
#  ['rosetinted',
#   'glasses',
#   'realism',
#   'investor',
#   'tension',
#   'iran',
#   'situation',
#   'eases',
#   'investors'],
#  ['99',
#   'waking',
#   'revolution',
#   'wakeup',
#   '2020vision',
#   'fakenews',
#   'questioneverything',
#   'rabbithole',
#   'redpill',
#   'truth'],
#  ['birth',
#   'federal',
#   'reservesubscribe',
#   'federalreserve',
#   'nyfed',
#   'incometaxes'],
#  ['jimwillie',
#   'federalreserve',
#   'buying',
#   'everything',
#   'sight',
#   'months',
#   'repo',
#   'transactions',
#   'failed'],
#  ['bond',
#   'report',
#   'treasury',
#   'yields',
#   'edge',
#   'lower',
#   'economic',
#   'data',
#   'draws',
#   'attention',
#   'investing',
#   'federalreserve'],
#  ['lost',
#   'decadethelostdecade',
#   'pujamehra',
#   'centreforpolicyresearchcdsbath',
#   'lehmanbrothers',
#   'merrilllynch'],
#  ['like',
#   'economy',
#   'high',
#   'inflation',
#   'high',
#   'costs',
#   'lack',
#   'good',
#   'quality',
#   'jobs',
#   'blame',
#   'federalreserve'],
#  ['tuesday',
#   'preview',
#   'call',
#   'investors',
#   'right',
#   'buy',
#   'latest',
#   'dips',
#   'risk',
#   'correlated',
#   'assets',
#   'key',
#   'tags'],
#  ['lost',
#   'decadethelostdecade',
#   'pujamehra',
#   'centreforpolicyresearchcdsbath',
#   'lehmanbrothers',
#   'merrilllynch'],
#  ['research',
#   'ripple',
#   'xrp',
#   'xrp',
#   'xrpcommunity',
#   'xrpthestandard',
#   'ripple',
#   'ripplenet'],
#  ['hackers',
#   'targetting',
#   'bangladesh',
#   'exportproceeds',
#   'cyberheist',
#   'stole',
#   'centralbank',
#   'money',
#   'deposited',
#   'ny'],
#  ['trump',
#   'tariffs',
#   'disappear',
#   'federalreserve',
#   'importantly',
#   'cut',
#   'interest',
#   'rates',
#   '1st',
#   'halfyear'],
#  ['video',
#   'familiar',
#   'federal',
#   'reserve',
#   'heres',
#   'quick',
#   'history',
#   'fed',
#   'federalreserve',
#   'fedpolicy'],
#  ['video',
#   'familiar',
#   'federal',
#   'reserve',
#   'heres',
#   'quick',
#   'history',
#   'fed',
#   'federalreserve',
#   'fedpolicy'],
#  ['courtesy', 'federalreserve'],
#  ['secrets', 'temple', 'federal', 'reserve', 'works', 'federalreserve'],
#  ['analysisafrica',
#   'highimpactflix',
#   'youtube',
#   'federalreserve',
#   'cfrunnewwprldorderbeholdapalehorse',
#   'yep',
#   'im',
#   'defi'],
#  ['meme',
#   'shroudedinsecrecy',
#   'dailyreminder',
#   'taxistheft',
#   'taxationistheft',
#   'taxation',
#   'taxes',
#   'taxesaretheft',
#   'tax'],
#  ['video',
#   'familiar',
#   'federal',
#   'reserve',
#   'heres',
#   'quick',
#   'history',
#   'fed',
#   'federalreserve',
#   'fedpolicy'],
#  ['fed',
#   'today',
#   '2001',
#   'federal',
#   'reserve',
#   'bank',
#   'philadelphia',
#   'charles',
#   'osgood',
#   'fed',
#   'federalreserve',
#   'money'],
#  ['federalreserve', 'globalistwhores', 'got', 'nailed'],
#  ['fed',
#   'best',
#   'friend',
#   'amp',
#   'proof',
#   'balancesheet',
#   'pudding',
#   'bbeu',
#   'db',
#   'dia',
#   'dxj',
#   'ewj',
#   'ezu',
#   'fez',
#   'gs'],
#  ['secrets', 'temple', 'federal', 'reserve', 'works', 'federalreserve'],
#  ['federalreserve',
#   'buying',
#   'everything',
#   'sight',
#   'months',
#   'repo',
#   'transactions',
#   'failed',
#   'fix',
#   'crisis',
#   'th'],
#  ['byron',
#   'wien',
#   'amp',
#   'joe',
#   'zidle',
#   'announce',
#   'ten',
#   'surprises',
#   '2020byronwien',
#   'outlook2020',
#   'markets',
#   'economy',
#   'economics',
#   'fed'],
#  ['qkellyl', 'deloitte', 'headquartered', 'uk', 'audits', 'federalreserve'],
#  ['video',
#   'familiar',
#   'federal',
#   'reserve',
#   'heres',
#   'quick',
#   'history',
#   'fed',
#   'federalreserve',
#   'fedpolicy'],
#  ['corporate',
#   'debt',
#   'nears',
#   'record',
#   '10',
#   'trillion',
#   'borrowing',
#   'binge',
#   'poses',
#   'new',
#   'risks',
#   'wpo'],
#  ['federalreserve',
#   'derivatives',
#   'fraud',
#   '6',
#   'trillion',
#   'six',
#   'weeksthis',
#   'figure',
#   'far',
#   'credible',
#   'daily'],
#  ['call',
#   'us',
#   '859',
#   '2236333',
#   'take',
#   'control',
#   'hardearned',
#   'savingsinvestwisely',
#   'federalreserve',
#   'savings'],
#  ['america',
#   'siege',
#   'endthefed',
#   'federalreserve',
#   'zionism',
#   'whitehouse',
#   'dancingisraelis'],
#  ['dyk',
#   'federalreserve',
#   'united',
#   'states',
#   'central',
#   'bank',
#   'created',
#   'december',
#   '1913',
#   'federal'],
#  ['lost',
#   'decadethelostdecade',
#   'pujamehra',
#   'centreforpolicyresearchcdsbath',
#   'lehmanbrothers',
#   'merrilllynch'],
#  ['former',
#   'federalreserve',
#   'chairman',
#   'ben',
#   'bernanke',
#   'delivered',
#   'called',
#   'relatively',
#   'upbeat',
#   'assessment',
#   'us',
#   'ce'],
#  ['secrets', 'temple', 'federal', 'reserve', 'works', 'federalreserve'],
#  ['three', 'interest', 'rate', 'cuts', '2019', 'investor', 'learn'],
#  ['new',
#   'slogan',
#   'federalreserve',
#   'print',
#   'money',
#   'currency',
#   'value',
#   'inflation',
#   'theft',
#   'tax',
#   'banks',
#   'control'],
#  ['follow',
#   'liveaturban',
#   'wednesday',
#   '9',
#   'central',
#   'highlights',
#   'cra',
#   'conversation',
#   'federalreserve',
#   'gov'],
#  ['iran', 'hacked', 'federalreserve'],
#  ['keep',
#   'work',
#   'bedroom',
#   'cartoon',
#   'cartoons',
#   'political',
#   'politicians',
#   'editorial',
#   'politicalcartoon'],
#  ['cnbc',
#   'bloomberg',
#   'foxbusiness',
#   'tools',
#   'federalreserve',
#   'print',
#   'money',
#   'give',
#   'bank'],
#  ['cnbc',
#   'foxbusiness',
#   'economy',
#   'great',
#   'federalreserve',
#   'giving',
#   'trillions',
#   'money',
#   'bank'],
#  ['cnbc',
#   'foxbusiness',
#   'want',
#   'kniw',
#   'secret',
#   'federalreserve',
#   'federal',
#   'reserve',
#   'fraud'],
#  ['bond',
#   'report',
#   '10year',
#   'treasury',
#   'yield',
#   'hangs',
#   '18',
#   'amid',
#   'heightened',
#   'midd',
#   'investing',
#   'federalreserve'],
#  ['federalreserve',
#   'ample',
#   'tools',
#   'fighting',
#   'potential',
#   'recession',
#   'even',
#   'though',
#   'benchmark',
#   'interest',
#   'rate',
#   'rem'],
#  ['federalreserve',
#   'ample',
#   'tools',
#   'fighting',
#   'potential',
#   'recession',
#   'even',
#   'though',
#   'benchmark',
#   'interest',
#   'rate',
#   'rem'],
#  ['federalreserve',
#   'prints',
#   '400',
#   'billion',
#   'past',
#   'four',
#   'months',
#   'bail',
#   'wallstreet',
#   'us',
#   'treasury',
#   'even'],
#  ['interestrates',
#   '2020here',
#   'federalreserve',
#   'may',
#   'stand',
#   'entire',
#   'yearfinance',
#   'money',
#   'business'],
#  ['cardpayments',
#   'accounted',
#   'threequarters',
#   'noncash',
#   'payments',
#   'us',
#   'amp',
#   'grew',
#   '9',
#   'annually',
#   '2015',
#   '2018'],
#  ['lost',
#   'decadethelostdecade',
#   'pujamehra',
#   'centreforpolicyresearchcdsbath',
#   'lehmanbrothers',
#   'merrilllynch'],
#  ['stacyherbert',
#   'ba',
#   'ponzified',
#   'stock',
#   'buybacks',
#   'w',
#   'free',
#   'money',
#   'congress',
#   'amp',
#   'federalreserve'],
#  ['wall',
#   'streets',
#   'worst',
#   'fears',
#   'yearend',
#   'funding',
#   'squeeze',
#   'never',
#   'materialized',
#   'thanks',
#   'large',
#   'part',
#   'quartertril'],
#  ['worldnews',
#   'watch',
#   'week',
#   'escalating',
#   'middleeast',
#   'tensions',
#   'india',
#   'reports',
#   'annual',
#   'gdp',
#   'estimate',
#   'tuesday'],
#  ['fed',
#   'quietly',
#   'confirms',
#   'fears',
#   'stock',
#   'markets',
#   '10',
#   'trillion',
#   'powder',
#   'keg',
#   'federalreserve',
#   'headlines',
#   'marketnews'],
#  ['end',
#   'year',
#   'federalreserve',
#   'hedged',
#   'repo',
#   'markets',
#   '58',
#   'billion',
#   'wealth',
#   'u'],
#  ['spending',
#   'us',
#   'construction',
#   'projects',
#   'rose',
#   'november',
#   'heres',
#   'experts',
#   'expect',
#   '2020',
#   'businessandmoney'],
#  ['lost',
#   'decadethelostdecade',
#   'pujamehra',
#   'centreforpolicyresearchcdsbath',
#   'lehmanbrothers',
#   'merrilllynch'],
#  ['snake',
#   'federalreserve',
#   'dog',
#   'stockmarket',
#   'thank',
#   'goodness',
#   'people',
#   'took',
#   'back'],
#  ['knowmorenews',
#   'englishlongbow',
#   'author',
#   'michael',
#   'hoffman',
#   'redicetv',
#   'feb',
#   '2013abdication',
#   'pope',
#   'amp',
#   'usury'],
#  ['us',
#   '10year',
#   'treasury',
#   'yields',
#   'seesaw',
#   'near',
#   'monthly',
#   'low',
#   'investing',
#   'federalreserve'],
#  ['cnbc',
#   'foxbusiness',
#   'know',
#   'secret',
#   'federalreserve',
#   'federal',
#   'reserve',
#   'spy',
#   'aapl',
#   'tsla'],
#  ['prediction',
#   'wk',
#   '1520please',
#   'share',
#   'donate',
#   'todjianasdaqeurusdusdjpywti'],
#  ['stick', 'irs', 'confessions', 'former', 'insiderattorney', 'audit'],
#  ['believe',
#   'us',
#   'dollar',
#   'backed',
#   'gold',
#   'genesismining',
#   'federalreserve',
#   'consumers',
#   'money',
#   'currency'],
#  ['dyk',
#   'twothirds',
#   'americans',
#   'dont',
#   '4yr',
#   'collegedegree',
#   'federalreserve',
#   'video',
#   'spotlights',
#   'jaime',
#   'pearson'],
#  ['december',
#   'sentiment',
#   'associated',
#   'federalreservejob',
#   'losses',
#   'losses',
#   'higher',
#   'higher',
#   'prices',
#   'led',
#   'job',
#   'tru'],
#  ['prediction',
#   'wk',
#   '1520please',
#   'share',
#   'donate',
#   'todjianasdaqeurusdusdjpywti'],
#  ['lost',
#   'decadethelostdecade',
#   'pujamehra',
#   'centreforpolicyresearchcdsbath',
#   'lehmanbrothers',
#   'merrilllynch'],
#  ['quantitative',
#   'easing',
#   'isnt',
#   'magic',
#   'wand',
#   'erases',
#   'ongoing',
#   'trade',
#   'war',
#   'war',
#   'iran',
#   'economics'],
#  ['fed',
#   'adds',
#   'another',
#   '577b',
#   'calm',
#   'markets',
#   '2020federalreserve',
#   'moneygame',
#   'cryptocurrencies'],
#  ['know',
#   '20',
#   'key',
#   'reads',
#   'sunday',
#   'emergingmarkets',
#   'energy',
#   'federalreserve',
#   'hedgefund',
#   'technology'],
#  ['qe4',
#   'head',
#   'us',
#   'federalreserve',
#   'jeromepowell',
#   'said',
#   'planetponzi',
#   'told'],
#  ['lost',
#   'decadethelostdecade',
#   'pujamehra',
#   'centreforpolicyresearchcdsbath',
#   'lehmanbrothers',
#   'merrilllynch'],
#  ['totallyfalse',
#   'truth',
#   'total',
#   'usdebt',
#   '2121',
#   'trillion70',
#   'owned',
#   'uspensionfunds',
#   'usentities'],
#  ['mirmakofficial',
#   'immtf7',
#   'totallyfalse',
#   'truth',
#   'total',
#   'usdebt',
#   '2121',
#   'trillion70',
#   'owned'],
#  ['antidefamation',
#   'league',
#   'torturing',
#   'sheeple',
#   'vaccines',
#   'fake',
#   'oscars',
#   'federalreserve'],
#  ['federalreserve',
#   'adds',
#   'another',
#   '577b',
#   'calm',
#   'markets',
#   '2020yet',
#   'another',
#   'case',
#   'bitcoin',
#   'federalreserve',
#   'ba'],
#  ['elerians',
#   'cautionary',
#   'optimism',
#   'fed',
#   'managing',
#   'economyvaluations',
#   'justified',
#   'reposition',
#   'gradually'],
#  ['right',
#   'usdollar',
#   'monitored',
#   'heavily',
#   'countries',
#   'restricting',
#   'access',
#   'necessities',
#   'civilians'],
#  ['hate',
#   'taxes',
#   'used',
#   'kill',
#   'one',
#   'guy',
#   'middle',
#   'east',
#   'responsible',
#   'defeating',
#   'isis'],
#  ['hint',
#   'distinctive',
#   'lack',
#   'centralbank',
#   'rothschilds',
#   'federalreserve',
#   'iran',
#   'ww3',
#   'trump',
#   'qanon'],
#  ['lost',
#   'decadethelostdecade',
#   'pujamehra',
#   'centreforpolicyresearchcdsbath',
#   'lehmanbrothers',
#   'merrilllynch'],
#  ['federalreserve',
#   'adds',
#   'another',
#   '577b',
#   'calm',
#   'markets',
#   '2020yet',
#   'another',
#   'case',
#   'bitcoin',
#   'btcbitcoinnews',
#   'news'],
#  ['worldiecom',
#   '9',
#   'boardofdirectors',
#   '3',
#   'wed',
#   'almost',
#   'federalreserve',
#   'w'],
#  ['bitcoin',
#   'genesis',
#   'block',
#   'mined',
#   '11',
#   'years',
#   'ago',
#   'happy',
#   'birthday',
#   'bitcoin',
#   'bitcoin'],
#  ['say', 'whatcrooks', 'protecting', 'bank', 'fraud', 'federalreserve'],
#  ['oldearthdissipationempirelost',
#   'confidenceimperialdeclineuncertaintydesperationillusionofprosperityengineerede'],
#  ['wife',
#   'worse',
#   'federalreserve',
#   'chairman',
#   'history',
#   'caused',
#   'many',
#   'financial',
#   'bubbles',
#   'including',
#   'housing'],
#  ['card',
#   'loan',
#   'growth',
#   '4',
#   'yoy',
#   'amp',
#   'cagr',
#   'rises',
#   '561',
#   'chase',
#   'citibank',
#   'bankofamerica',
#   'capitalone'],
#  ['lost',
#   'decadethelostdecade',
#   'pujamehra',
#   'centreforpolicyresearchcdsbath',
#   'lehmanbrothers',
#   'merrilllynch'],
#  ['must',
#   'read',
#   'add',
#   'listput',
#   'fiction',
#   'whilemake',
#   'high',
#   'priority',
#   'read'],
#  ['fed',
#   'would',
#   'like',
#   'stay',
#   'sideline',
#   '2020',
#   'investing',
#   'pro',
#   'economy',
#   'useconomy',
#   'stocks',
#   'stockmarket',
#   'federalreserve'],
#  ['target',
#   'probabilities',
#   'feds',
#   'jan',
#   '29',
#   'meetingtraders',
#   'see',
#   '72',
#   'probability',
#   '25bps',
#   'rate',
#   'hike',
#   'f'],
#  ['federal',
#   'reserve',
#   'monday',
#   'announced',
#   'support',
#   'third',
#   'settlement',
#   'window',
#   'day',
#   'sameday',
#   'automated',
#   'clear'],
#  ['know',
#   '15',
#   'key',
#   'reads',
#   'saturday',
#   'dowjones',
#   'energy',
#   'federalreserve',
#   'homebuilders',
#   'oil',
#   'retail',
#   'trump'],
#  ['consumer',
#   'debt',
#   'ratios',
#   'hit',
#   '40',
#   'yr',
#   'low',
#   'bears',
#   'awaken',
#   'dsr',
#   'federalreserve',
#   'revolvingcredit',
#   'creditcarddebt'],
#  ['expected',
#   'fed',
#   'funds',
#   'ratechart',
#   'showing',
#   'fed',
#   'funds',
#   'futures',
#   'january',
#   '2021',
#   'imply',
#   'expected',
#   'rate',
#   '130'],
#  ['lost',
#   'decadethelostdecade',
#   'pujamehra',
#   'centreforpolicyresearchcdsbath',
#   'lehmanbrothers',
#   'merrilllynch'],
#  ['hft',
#   'videocast',
#   'stock',
#   'market',
#   'commentary',
#   'weekly',
#   'recap',
#   'episode',
#   '10',
#   'china',
#   'cnbc',
#   'commodities',
#   'earnings',
#   'energy'],
#  ['fed',
#   'adds',
#   '57b',
#   'marketsheatmap',
#   'column',
#   '3gt',
#   'monetarypolicy',
#   'financialrepression'],
#  ['federalreserve',
#   'agreed',
#   'keep',
#   'current',
#   'interest',
#   'rates',
#   'unchanged',
#   'timegold',
#   'prices',
#   'rose',
#   'nearly',
#   '13'],
#  ['lost',
#   'decadethelostdecade',
#   'pujamehra',
#   'centreforpolicyresearchcdsbath',
#   'lehmanbrothers',
#   'merrilllynch'],
#  ['leahlaw23536852',
#   '5horsesquad1',
#   'eyesofcharlie',
#   'realdonaldtrump',
#   'thejusticedept',
#   'bet',
#   'barackobama',
#   'deal',
#   'g'],
#  ['know',
#   'federal',
#   'reserve',
#   'bank',
#   'createdwhy',
#   'paper',
#   'money',
#   'backed',
#   'gold'],
#  ['federal',
#   'reserve',
#   'enslaved',
#   'us',
#   'behind',
#   'deep',
#   'statein',
#   'episode',
#   'behind',
#   'deep',
#   'state',
#   'host',
#   'alex',
#   'new'],
#  ['spy',
#   'qqq',
#   'dia',
#   'federalreserve',
#   'last',
#   'month',
#   'saw',
#   'declining',
#   'risk',
#   'recession',
#   'reveal',
#   'minutes'],
#  ['us',
#   'person',
#   'vassal',
#   'deposittweet',
#   '2',
#   '2unitedstates',
#   'federal',
#   'contract',
#   'federalreserve'],
#  ['us',
#   'person',
#   'vassal',
#   'deposittweet',
#   '1',
#   '2unitedstates',
#   'federal',
#   'contract',
#   'federalreserve'],
#  ['one',
#   'betweet',
#   '2',
#   '2federalreserve',
#   'unitedstates',
#   'currencytrading',
#   'intellectualproperty'],
#  ['one',
#   'betweet',
#   '1',
#   '2federalreserve',
#   'unitedstates',
#   'currencytrading',
#   'intellectualproperty'],
#  ['federalreserve',
#   'carefully',
#   'monitoring',
#   'excessive',
#   'borrowing',
#   'businesses',
#   'leaves',
#   'vulnerable',
#   'distress'],
#  ['federalreserve',
#   'watching',
#   'elevated',
#   'valuation',
#   'pressures',
#   'asset',
#   'prices',
#   'high',
#   'relative',
#   'economic',
#   'fu'],
#  ['thesolarireport',
#   'could',
#   'linkup',
#   'fasab',
#   '56',
#   'ie',
#   'taking',
#   'federal',
#   'budget',
#   'dark',
#   'given',
#   'massive',
#   'scale'],
#  ['federalreserve',
#   'officials',
#   'indicated',
#   'hurry',
#   'reverse',
#   'last',
#   'years',
#   'rate',
#   'cuts',
#   'met',
#   'middec'],
#  ['digichamber',
#   'federalreserve',
#   'fomc',
#   'interestrates',
#   'strong',
#   'labor',
#   'market',
#   'moderate',
#   'growth',
#   'cited',
#   'fomc',
#   'rate',
#   'decision'],
#  ['secrets', 'temple', 'federal', 'reserve', 'works', 'federalreserve'],
#  ['2010s',
#   'decade',
#   'big',
#   'government',
#   'fueled',
#   'federalreserve',
#   'writes',
#   'andrewliberty23'],
#  ['easing',
#   'downside',
#   'risks',
#   'comfort',
#   'fomc',
#   'members',
#   'usecon',
#   'fomc',
#   'federalreserve'],
#  ['polipsyche',
#   'jeromecorsi',
#   'bikerbd',
#   'realdonaldtrump',
#   'rudygiuliani',
#   'robherring',
#   'msmliars',
#   'foxnewssunday',
#   'thefive'],
#  ['oannewsroom',
#   'federalreserve',
#   'kristianrouz',
#   'fed',
#   'drops',
#   'billions',
#   'helicopter',
#   'money',
#   'amid',
#   'crisis',
#   'fears'],
#  ['federal',
#   'reserve',
#   'last',
#   'month',
#   'saw',
#   'declining',
#   'risk',
#   'recession',
#   'federal',
#   'reserves',
#   'signaled',
#   'expected'],
#  ['wwiii',
#   'tehran',
#   'iran',
#   'bitcoin',
#   'gold',
#   'silver',
#   'messiah',
#   'louisfarrakhan',
#   'warns',
#   'money',
#   'federalreserve',
#   'ba'],
#  ['federalreserve',
#   'feds',
#   '2020002',
#   'monetary',
#   'policy',
#   'birth',
#   'rates',
#   'effect',
#   'mortgage',
#   'rate',
#   'passthrough',
#   'fertil'],
#  ['wwiii',
#   'tehran',
#   'bitcoin',
#   'economy',
#   'messiah',
#   'louisfarrakhan',
#   'warns',
#   'year',
#   'federalreserve',
#   'act'],
#  ['wwiii',
#   'economy',
#   'bitcoin',
#   'federalreserve',
#   'messiah',
#   'louisfarrakhan',
#   'warns',
#   'fascists',
#   'advocate',
#   'creation',
#   'singl'],
#  ['dollar',
#   'pyramid',
#   'keeps',
#   'growing',
#   'wait',
#   'russia',
#   'china',
#   'join',
#   'forming',
#   'new',
#   'worldbank'],
#  ['wwiii',
#   'iran',
#   'messiah',
#   'louisfarrakhan',
#   'warns',
#   'federalreserve',
#   'synagogue',
#   'satan',
#   'god',
#   'came',
#   'destroy',
#   'sata'],
#  ['fomc',
#   'minutes',
#   'hint',
#   'restiveness',
#   'policy',
#   'much',
#   'contentment',
#   'wthe',
#   'current',
#   'standstill',
#   'stance',
#   'vario'],
#  ['federalreserve',
#   'minutes',
#   'federal',
#   'open',
#   'market',
#   'committee',
#   'december',
#   '1011',
#   '2019'],
#  ['minutes',
#   'federal',
#   'open',
#   'market',
#   'committee',
#   'december',
#   '1011',
#   '2019',
#   'bank',
#   'fed'],
#  ['fomc',
#   'minutes',
#   'surprises',
#   'even',
#   'much',
#   'interesting',
#   'discussion',
#   'appropriate',
#   'fomc',
#   'federalreserve',
#   'anthonymace'],
#  ['join',
#   'today',
#   'bloomberg',
#   'european',
#   'open',
#   'frankfurt',
#   'discuss',
#   'fed',
#   'minutes',
#   'geopolitical',
#   'risk',
#   'outlook'],
#  ['wwiii',
#   'bitcoin',
#   'messiah',
#   'louisfarrakhan',
#   'warns',
#   'executiveorder',
#   'jfk',
#   'signed',
#   'took',
#   'away',
#   'power'],
#  ['consumers',
#   'struggle',
#   'card',
#   'payments',
#   'juiced',
#   'economy',
#   'delinquency',
#   'top100',
#   'banks',
#   'capital'],
#  ['bitcoin',
#   'economy',
#   'satanic',
#   'controlled',
#   'fakenews',
#   'tries',
#   'deceive',
#   'us',
#   'believing',
#   'president',
#   'trump',
#   'power'],
#  ['bond',
#   'report',
#   'treasurys',
#   'rally',
#   'accelerates',
#   'weakest',
#   'ism',
#   'factory',
#   'readin',
#   'investing',
#   'federalreserve'],
#  ['cleveland',
#   'feds',
#   'mesterbloomberg',
#   'corporate',
#   'debt',
#   'levels',
#   'among',
#   '2020',
#   'concerns',
#   'mind',
#   'trade',
#   'still',
#   'worry',
#   'fo'],
#  ['corockymtns',
#   'jeromecorsi',
#   'bikerbd',
#   'realdonaldtrump',
#   'rudygiuliani',
#   'robherring',
#   'msmliars',
#   'foxnewssunday',
#   'thefive'],
#  ['secrets', 'temple', 'federal', 'reserve', 'works', 'federalreserve'],
#  ['fraudulent',
#   'reserve',
#   'federalreserve',
#   'wasnt',
#   'injecting',
#   'cash',
#   'regular',
#   'market',
#   'would',
#   'easily',
#   '10'],
#  ['10year',
#   'swap',
#   'rates',
#   'guts',
#   'say',
#   'still',
#   'heading',
#   'higher',
#   'interestrates',
#   'economics'],
#  ['chi',
#   'feds',
#   'evanscnbc',
#   'repositioning',
#   'reserves',
#   'ample',
#   'mode',
#   'standing',
#   'repo',
#   'facility',
#   'cenbanks'],
#  ['chi',
#   'feds',
#   'evanscnbc',
#   'soft',
#   'dec',
#   'mfg',
#   'ism',
#   'trade',
#   'less',
#   'ag',
#   'demand',
#   'seeing',
#   'economy',
#   'expand',
#   'mfg',
#   'weak',
#   'c'],
#  ['chi',
#   'feds',
#   'evamscnbc',
#   'think',
#   '35',
#   'unemployment',
#   'likely',
#   'continue',
#   'dont',
#   'see',
#   'big',
#   'inflation',
#   'risk',
#   'monitorin'],
#  ['chi',
#   'feds',
#   'evanscnbc',
#   'overall',
#   'without',
#   'inflationary',
#   'pressures',
#   'good',
#   'setting',
#   'need',
#   'keep',
#   'promotin'],
#  ['chi',
#   'feds',
#   'evanscnbc',
#   'early',
#   'assess',
#   'aftereffects',
#   'iranus',
#   'developments',
#   'see',
#   '225',
#   'growth',
#   '2020'],
#  ['stormisuponus',
#   'continue',
#   'withno',
#   'irs',
#   'electricity',
#   'companies',
#   'oamprno',
#   'federalreserve'],
#  ['banks',
#   'looking',
#   'fed',
#   'minutes',
#   'shed',
#   'light',
#   'repo',
#   'market',
#   'heading',
#   'new',
#   'year',
#   'repo'],
#  ['birth',
#   'federal',
#   'reservesubscribe',
#   'federalreserve',
#   'nyfed',
#   'incometaxes'],
#  ['federalreserve',
#   'feds',
#   '2020001',
#   'power',
#   'narratives',
#   'economic',
#   'forecasts'],
#  ['el33th4xor',
#   'sallymayweather',
#   'youre',
#   'saying',
#   'people',
#   'federalreserve',
#   'great',
#   'people',
#   'far',
#   'kno'],
#  ['federalreservebc', 'january', '03', '2020', 'via', 'gocomics'],
#  ['democratic',
#   'peoples',
#   'republic',
#   'us',
#   'monetary',
#   'policy',
#   'goldmansachs',
#   'creditsuisse'],
#  ['federalreserve',
#   'rouge',
#   'hedge',
#   'fund',
#   'bank',
#   'nothing',
#   'federal',
#   'government',
#   'amp',
#   'ove'],
#  ['fed',
#   'minutes',
#   'repos',
#   'rates',
#   'centralbank',
#   'fedeasing',
#   'federalreserve'],
#  ['representative',
#   'perhaps',
#   'instead',
#   'interest',
#   'cost',
#   'heres',
#   'one',
#   'principal',
#   'repayment',
#   'includedstill',
#   'ex'],
#  ['eurusd',
#   'achieved',
#   'tpt1',
#   '11155',
#   'book',
#   'profit',
#   '400',
#   'per',
#   'lotcopytrading',
#   'bestforexsignal',
#   'forex',
#   'forextrading'],
#  ['geopolitical',
#   'tension',
#   'heats',
#   'triggering',
#   'liquidation',
#   'record',
#   'high',
#   'stocks',
#   'safe',
#   'assets',
#   'rally',
#   'conse'],
#  ['looks',
#   'like',
#   'military',
#   'industrial',
#   'complex',
#   'get',
#   'war',
#   'middle',
#   'east',
#   'maybe',
#   'trump',
#   'plunge'],
#  ['guess',
#   'unitedstates',
#   'corporation',
#   'supremecourt',
#   'really',
#   'works',
#   'dunandbradstreet',
#   'justiceiscoming'],
#  ['amazed',
#   'see',
#   'multi',
#   'trillion',
#   'usmarket',
#   'trading',
#   'like',
#   'pennystocks',
#   'thank',
#   'federalreserve',
#   'algotrading'],
#  ['judywoodruff',
#   'newshour',
#   'lisadnews',
#   'nickschifrin',
#   'trump',
#   'created',
#   'bloated',
#   'false',
#   'economy',
#   'using'],
#  ['earth',
#   'wind',
#   'amp',
#   'fire',
#   'shining',
#   'star',
#   'stock',
#   'market',
#   'sentiment',
#   'results',
#   'check',
#   'latest',
#   'weekly',
#   'note'],
#  ['ron',
#   'paul',
#   'forget',
#   'russians',
#   'federalreserve',
#   'meddling',
#   'us',
#   'elections'],
#  ['chris',
#   'back',
#   'beverly',
#   'hills',
#   'net',
#   'lease',
#   'finance',
#   'options',
#   'monetarypolicy',
#   'markets'],
#  ['us',
#   'federalreserve',
#   'pumps',
#   'extra',
#   'billions',
#   'american',
#   'economy',
#   'amp',
#   'cuts',
#   'rates',
#   'prop',
#   'us',
#   'record',
#   'debt',
#   'def'],
#  ['federalreserve', 'sets', '2019', 'global', 'indicator', 'amounts', 'gsibs'],
#  ['plenty',
#   'news',
#   'recently',
#   'case',
#   'missed',
#   'study',
#   'federalreserve',
#   'economy',
#   'tariffs'],
#  ['credit',
#   'card',
#   'losses',
#   'tick',
#   'new',
#   'highs',
#   'despite',
#   'economy',
#   'citibank',
#   'chase',
#   'capitalone',
#   'bankofame'],
#  ['mortgage',
#   'credit',
#   'risk',
#   'retention',
#   'rules',
#   'review',
#   'regulators',
#   'fdic',
#   'federalreserve',
#   'usocc'],
#  ['three', 'interest', 'rate', 'cuts', '2019', 'investor', 'learn'],
#  ['us',
#   'fomc',
#   'meeting',
#   'minutes',
#   '15',
#   'minutes',
#   'stockmarket',
#   'fomc',
#   'federalreserve'],
#  ['jdryan5000',
#   'dearauntcrabby',
#   'dt',
#   'also',
#   'federalreserve',
#   'pumping',
#   'freshly',
#   'printed',
#   'money',
#   'markets',
#   'c'],
#  ['new',
#   'blog',
#   'end',
#   'traditional',
#   'monetary',
#   'policy',
#   'dr',
#   'james',
#   'caton',
#   'via',
#   'aier',
#   'soundmoneyproj',
#   'macroeconomics'],
#  ['would',
#   'appear',
#   'banking',
#   'members',
#   'federalreserve',
#   'sure',
#   'approval',
#   'management'],
#  ['big',
#   'tech',
#   'leads',
#   'decline',
#   'core',
#   'earnings',
#   'seekingalpha',
#   'tech',
#   'earnings',
#   'bubbles',
#   'russell'],
#  ['would',
#   'take',
#   'spark',
#   'global',
#   'financial',
#   'crisis',
#   '2020',
#   'worth',
#   'us',
#   'financials'],
#  ['ep',
#   '332',
#   'conspiracy',
#   'unlimited',
#   'arrived',
#   'bank',
#   'canada',
#   'conspiracy',
#   'listen',
#   '2',
#   'conversation',
#   'w',
#   'lawyer'],
#  ['bond',
#   'report',
#   'treasury',
#   'yields',
#   'slip',
#   'even',
#   'global',
#   'stocks',
#   'rally',
#   'kick',
#   'investing',
#   'federalreserve'],
#  ['expect', 'dramafree', 'federalreserve', '2020'],
#  ['hard',
#   'drives',
#   'smashed',
#   'bleachbit',
#   'perjury',
#   'foundation',
#   'mills',
#   'lynch',
#   'billclinton',
#   'tarmac',
#   'johnkerry',
#   'comey',
#   'priestap'],
#  ['weve',
#   'screwed',
#   'since',
#   'day',
#   'one',
#   'trump',
#   'trumptariffs',
#   'federalreserve'],
#  ['earth',
#   'wind',
#   'amp',
#   'fire',
#   'shining',
#   'star',
#   'stock',
#   'market',
#   'sentiment',
#   'results',
#   'china',
#   'earnings',
#   'energy',
#   'estimates'],
#  ['yikes',
#   'mortgagerates',
#   'could',
#   'trend',
#   'upward',
#   '2020',
#   'humming',
#   'economy',
#   'halt',
#   'federalreserve',
#   'interestrate'],
#  ['18min',
#   'history',
#   'tavistock',
#   'institute',
#   'human',
#   'relations',
#   'promoting',
#   'oneworld',
#   'government',
#   'using',
#   'mindcontrol'],
#  ['unlike',
#   'federalreserve',
#   'pumping',
#   'much',
#   'unbacked',
#   'currency',
#   'system',
#   'order',
#   'fuel',
#   'unsustainable',
#   'debt',
#   'crisis'],
#  ['rockingangelbmi',
#   'catheri71000729',
#   'seems',
#   'like',
#   'fbi',
#   'federal',
#   'fake',
#   'federalreserve'],
#  ['us',
#   'treasury',
#   'sec',
#   'mnuchin',
#   'head',
#   'delegation',
#   'davos',
#   'wef',
#   'later',
#   'month',
#   'investing',
#   'federalreserve'],
#  ['boom', 'federalreserve', 'kims'],
#  ['video',
#   'familiar',
#   'federal',
#   'reserve',
#   'heres',
#   'quick',
#   'history',
#   'fed',
#   'federalreserve',
#   'fedpolicy'],
#  ['federalreserve',
#   'says',
#   'tariffs',
#   'china',
#   'failed',
#   'hurt',
#   'jobs',
#   'amp',
#   'productivity',
#   'costing',
#   'end',
#   'wo'],
#  ['secrets', 'temple', 'federal', 'reserve', 'works', 'federalreserve'],
#  ['federalreserve',
#   'basically',
#   'tariffs',
#   'backfiredtariffs',
#   'thus',
#   'far',
#   'led',
#   'increased',
#   'activity'],
#  ['usury',
#   'sweden',
#   'tested',
#   'cashless',
#   'creates',
#   'money',
#   'control',
#   'cashlesssociety',
#   'surveillancesociety'],
#  ['secrets', 'temple', 'federal', 'reserve', 'works', 'federalreserve'],
#  ['central',
#   'banks',
#   'debase',
#   'currency',
#   'qe',
#   'nir',
#   'get',
#   'endthefed',
#   'federalreserve',
#   'printing'],
#  ['chiefpolice2',
#   'christinaestab1',
#   'please',
#   'listen',
#   'quick',
#   'youtube',
#   'scary',
#   'interesting',
#   'things',
#   'say'],
#  ['americans',
#   'tapping',
#   'holiday',
#   'credit',
#   'oct',
#   'surprise',
#   'debt',
#   'consumercredit',
#   'spending',
#   'economy'],
#  ['vetsv',
#   'great',
#   'article',
#   'thx',
#   'buddy',
#   'bring',
#   'inflation',
#   'keep',
#   'powder',
#   'dry',
#   '2nd',
#   'half',
#   'decade',
#   'everythin'],
#  ['epstein',
#   'deutshebank',
#   'amp',
#   'federalreserve',
#   'college',
#   'admissionsscandal',
#   'amp',
#   'college',
#   'girls',
#   'softprostitution'],
#  ['getanalysis',
#   'recordtrillions',
#   'printedmoney',
#   'pumped',
#   'global',
#   'financialsystems',
#   'pastdecade'],
#  ['video',
#   'familiar',
#   'federal',
#   'reserve',
#   'heres',
#   'quick',
#   'history',
#   'fed',
#   'federalreserve',
#   'fedpolicy'],
#  ['video',
#   'familiar',
#   'federal',
#   'reserve',
#   'heres',
#   'quick',
#   'history',
#   'fed',
#   'federalreserve',
#   'fedpolicy'],
#  ['video',
#   'familiar',
#   'federal',
#   'reserve',
#   'heres',
#   'quick',
#   'history',
#   'fed',
#   'federalreserve',
#   'fedpolicy'],
#  ['end',
#   'federalreserve',
#   'hatched',
#   'thru',
#   'trickery',
#   'secrecy',
#   'amp',
#   'pure',
#   'evilness',
#   '1st',
#   'place'],
#  ['americans',
#   'jump',
#   'start',
#   'holiday',
#   'credit',
#   'card',
#   'debt',
#   'federalreserve',
#   'creditcards',
#   'spending'],
#  ['card',
#   'late',
#   'payers',
#   'continue',
#   'rise',
#   'despite',
#   'job',
#   'glut',
#   'delinquency',
#   'q3',
#   'federalreserve'],
#  ['easy',
#   'understand',
#   'high',
#   'cost',
#   'health',
#   'insurance',
#   'folks',
#   'federalreserve',
#   'insurance'],
#  ['repost',
#   'keepseeking101the',
#   'federalreserve',
#   'fractionalreservebanking',
#   'militaryindustrialcomplex'],
#  ['michaeljohns',
#   'sujatasage',
#   'wowthat',
#   'sounds',
#   'awfully',
#   'similar',
#   'jp',
#   'morgan',
#   'early',
#   '1900s',
#   'story',
#   'creation'],
#  ['global',
#   'expansion',
#   'mitigates',
#   'recessions',
#   'impacts',
#   'techtalent',
#   'federalreserve'],
#  ['hope',
#   'usa',
#   'goptaxcuts',
#   'must',
#   'amp',
#   'corporations',
#   'required',
#   'practice',
#   'taxevasionpay',
#   'incometaxes']]

# %%
# Create a counter to return the most commonly used words and the number of times that they are used.
all_words_nsw = list(itertools.chain(*tweets_nsw))
counts_nsw = collections.Counter(all_words_nsw)
counts_nsw.most_common(15)
# Out:
# [('federalreserve', 140),
#  ('federal', 39),
#  ('reserve', 29),
#  ('fed', 27),
#  ('us', 22),
#  ('money', 20),
#  ('economy', 18),
#  ('amp', 16),
#  ('lost', 15),
#  ('decadethelostdecade', 15),
#  ('pujamehra', 15),
#  ('centreforpolicyresearchcdsbath', 15),
#  ('lehmanbrothers', 15),
#  ('merrilllynch', 15),
#  ('history', 14)]

# %%
clean_tweets_nsw = pd.DataFrame(counts_nsw.most_common(15),
                             columns=['words', 'count'])

fig, ax = plt.subplots(figsize=(8, 8))

# Plot horizontal bar graph
clean_tweets_nsw.sort_values(by='count').plot.barh(x='words',
                      y='count',
                      ax=ax,
                      color="red")

ax.set_title("Common Words Found in Tweets after Stopwords filter")

plt.show()

# %%
# Remove collection words. Collection words are the words that you used to query your data from Twitter. 
# This This could skew your word frequency analysis.

collection_words = ['#federalreserve', 'federalreserve', 'fed','reserve', 'federal','us']
tweets_nsw_nc = [[w for w in word if not w in collection_words]
                 for word in tweets_nsw]

# Flatten list of words in clean tweets
all_words_nsw_nc = list(itertools.chain(*tweets_nsw_nc))

# Create counter of words in clean tweets
counts_nsw_nc = collections.Counter(all_words_nsw_nc)

counts_nsw_nc.most_common(15)
# Out:
# [('money', 20),
#  ('economy', 18),
#  ('amp', 16),
#  ('lost', 15),
#  ('decadethelostdecade', 15),
#  ('pujamehra', 15),
#  ('centreforpolicyresearchcdsbath', 15),
#  ('lehmanbrothers', 15),
#  ('merrilllynch', 15),
#  ('history', 14),
#  ('feds', 12),
#  ('rate', 12),
#  ('markets', 11),
#  ('heres', 11),
#  ('bitcoin', 11)]

# %%
clean_tweets_ncw = pd.DataFrame(counts_nsw_nc.most_common(15),
                             columns=['words', 'count'])

fig, ax = plt.subplots(figsize=(8, 8))

# Plot horizontal bar graph
clean_tweets_ncw.sort_values(by='count').plot.barh(x='words',
                      y='count',
                      ax=ax,
                      color="green")

ax.set_title("Common Words Found in Tweets (Excluding the Stop or Collection Words)")

plt.show()

# %%
# Create list of lists containing bigrams in tweets
terms_bigram = [list(bigrams(tweet)) for tweet in tweets_nsw_nc]

# Flatten list of bigrams in clean tweets
bigrams = list(itertools.chain(*terms_bigram))

# Create counter of words in clean bigrams
bigram_counts = collections.Counter(bigrams)

bigram_counts.most_common(20)
# Out:
# [(('lost', 'decadethelostdecade'), 15),
#  (('decadethelostdecade', 'pujamehra'), 15),
#  (('pujamehra', 'centreforpolicyresearchcdsbath'), 15),
#  (('centreforpolicyresearchcdsbath', 'lehmanbrothers'), 15),
#  (('lehmanbrothers', 'merrilllynch'), 15),
#  (('video', 'familiar'), 9),
#  (('familiar', 'heres'), 9),
#  (('heres', 'quick'), 9),
#  (('quick', 'history'), 9),
#  (('history', 'fedpolicy'), 9),
#  (('secrets', 'temple'), 8),
#  (('temple', 'works'), 8),
#  (('bond', 'report'), 6),
#  (('monetary', 'policy'), 5),
#  (('interest', 'rate'), 5),
#  (('treasury', 'yields'), 5),
#  (('messiah', 'louisfarrakhan'), 5),
#  (('louisfarrakhan', 'warns'), 5),
#  (('chi', 'feds'), 5),
#  (('report', 'treasury'), 4)]

# %%
bigram_df = pd.DataFrame(bigram_counts.most_common(20),
                             columns=['bigram', 'count'])

# %%
# Create dictionary of bigrams and their counts
d = bigram_df.set_index('bigram').T.to_dict('records')
# Create network plot 
G = nx.Graph()

# Create connections between nodes
for k, v in d[0].items():
    G.add_edge(k[0], k[1], weight=(v * 10))

G.add_node("bitcoin", weight=100)
fig, ax = plt.subplots(figsize=(10, 8))

pos = nx.spring_layout(G, k=1)

# Plot networks
nx.draw_networkx(G, pos,
                 font_size=16,
                 width=3,
                 edge_color='grey',
                 node_color='purple',
                 with_labels = False,
                 ax=ax)

# Create offset labels
for key, value in pos.items():
    x, y = value[0]+.135, value[1]+.045
    ax.text(x, y,
            s=key,
            bbox=dict(facecolor='red', alpha=0.25),
            horizontalalignment='center', fontsize=13)
    
plt.show()

# %%
text = counts_nsw_nc
wordcloud = WordCloud(
    width = 3000,
    height = 2000,
    background_color = 'black',
    stopwords = STOPWORDS).generate(str(text))
fig = plt.figure(
    figsize = (40, 30),
    facecolor = 'k',
    edgecolor = 'k')
plt.imshow(wordcloud, interpolation = 'bilinear')
plt.axis('off')
plt.tight_layout(pad=0)
plt.show()
